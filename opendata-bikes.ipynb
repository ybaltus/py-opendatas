# %%
#!pip install matplotlib
#!pip install numpy

# %%
# Render our plots inline
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (15, 10)

# %% [markdown]
# # 1 Charger de la donnée

# %% [markdown]
# Nous allons étudier un dataset représentant la fréquentation quotidienne de 7 pistes cyclables Montréalaises en 2012.
#
# Charger le dataset bikes.csv en utilisant la méthode `read_csv` de pandas.
#
# Jetez un coup d'oeil à la documentation => https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html

# %%
df=pd.read_csv('data/bikes.csv', encoding='latin1')

# %% [markdown]
# Afficher les 3 premières lignes.

# %%
df.head(3)
# Out:
#   Date;Berri 1;Brébeuf (données non disponibles);Côte-Sainte-Catherine;Maisonneuve 1;Maisonneuve 2;du Parc;Pierre-Dupuy;Rachel1;St-Urbain (données non disponibles)
# 0                   01/01/2012;35;;0;38;51;26;10;16;
# 1                   02/01/2012;83;;1;68;153;53;6;43;
# 2                 03/01/2012;135;;2;104;248;89;3;58;

# %% [markdown]
# Comme on peut le voir, le dataset n'est pas proprement chargé, toutes les colonnes sont reunies en une. Pour arranger ceci, nous allons utiiser quelques arguments de la méthode `read_csv`.
#
# * changer le separateur de colonne a `;` avec l'option `sep`
# * "Parser" la colonne date avec l'option `parse_date`
# * Changer les dates pour avoir le jour et non le mois en premier
# * Definir la colonne 'Date' comme index du dataframe avec `index_col`

# %%
df=pd.read_csv('data/bikes.csv', encoding='latin1', sep=';', parse_dates=True, index_col='Date', dayfirst=True)

# %%
df
# Out:
#             Berri 1  Brébeuf (données non disponibles)  Côte-Sainte-Catherine  \
# Date
# 2012-01-01       35                                NaN                      0
# 2012-01-02       83                                NaN                      1
# 2012-01-03      135                                NaN                      2
# 2012-01-04      144                                NaN                      1
# 2012-01-05      197                                NaN                      2
# ...             ...                                ...                    ...
# 2012-11-01     2405                                NaN                   1208
# 2012-11-02     1582                                NaN                    737
# 2012-11-03      844                                NaN                    380
# 2012-11-04      966                                NaN                    446
# 2012-11-05     2247                                NaN                   1170
#
# ...

# %%
df.head(3)
# Out:
#             Berri 1  Brébeuf (données non disponibles)  Côte-Sainte-Catherine  \
# Date
# 2012-01-01       35                                NaN                      0
# 2012-01-02       83                                NaN                      1
# 2012-01-03      135                                NaN                      2
#
#             Maisonneuve 1  Maisonneuve 2  du Parc  Pierre-Dupuy  Rachel1  \
# Date
# 2012-01-01             38             51       26            10       16
# 2012-01-02             68            153       53             6       43
# 2012-01-03            104            248       89             3       58
#
#             St-Urbain (données non disponibles)
# Date
# 2012-01-01                                  NaN
# 2012-01-02                                  NaN
# 2012-01-03                                  NaN

# %% [markdown]
# # 1.1 Sélection d'une colonne

# %% [markdown]
# On peut selectionner une colonne (ou plusieurs) d'un dataframe de la même manière que l'on slectionne une clé dans un dictionnaire :
# `df['column_name']` or `df[['col1', 'col2', etc]]`
#
# Selectionner la colonne 'Berri 1'

# %%
colonne_berri1 = df['Berri 1']

# %%
print(colonne_berri1)
# Out:
# Date
# 2012-01-01      35
# 2012-01-02      83
# 2012-01-03     135
# 2012-01-04     144
# 2012-01-05     197
#               ...
# 2012-11-01    2405
# 2012-11-02    1582
# 2012-11-03     844
# 2012-11-04     966
# 2012-11-05    2247
# Name: Berri 1, Length: 310, dtype: int64

# %% [markdown]
# # 1.2 "Plotter" une colonne

# %% [markdown]
# Utiliser la méthode `.plot()` pour produire une graphique del la frequentation de la piste tout au long de l'année.
#
# On remarque sans surprise que peu de gens prennent le vélo en hiver.

# %%
df['Berri 1'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# On peut aussi plotter toutes les colonnes du dataframe en utilisant le même mechanisme.

# %%
df.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# Cependant, c'est un peu illisible... Utiliser l'option `subplots=True` pour séparer les courbes.

# %%
df.plot(subplots=True)
# Out:
# array([<AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>], dtype=object)

# %% [markdown]
# # 2 Premières analyses

# %% [markdown]
# Dans cette partie nous allons utiliser un nouveau jeu de données plus volumineux, représentant les appels au service 311 de la ville de New York.
#
# Charger le fichier '311-service-requests.csv' dans un dataframe pandas.

# %%
df=pd.read_csv('data/311-service-requests.csv')
df
# Out:
# /tmp/ipykernel_12347/3581604325.py:1: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('data/311-service-requests.csv')
#         Unique Key            Created Date             Closed Date Agency  \
# 0         26589651  10/31/2013 02:08:41 AM                     NaN   NYPD
# 1         26593698  10/31/2013 02:01:04 AM                     NaN   NYPD
# 2         26594139  10/31/2013 02:00:24 AM  10/31/2013 02:40:32 AM   NYPD
# 3         26595721  10/31/2013 01:56:23 AM  10/31/2013 02:21:48 AM   NYPD
# 4         26590930  10/31/2013 01:53:44 AM                     NaN  DOHMH
# ...            ...                     ...                     ...    ...
# 111064    26426013  10/04/2013 12:01:13 AM  10/07/2013 04:07:16 PM    DPR
# 111065    26428083  10/04/2013 12:01:05 AM  10/04/2013 02:13:50 AM   NYPD
# 111066    26428987  10/04/2013 12:00:45 AM  10/04/2013 01:25:01 AM   NYPD
# ...

# %% [markdown]
# # 2.1 Description du df

# %% [markdown]
# Explorer le dataframe avec les methodes .info(), .summary(), .describe()

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111069 entries, 0 to 111068
# Data columns (total 52 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Unique Key                      111069 non-null  int64
#  1   Created Date                    111069 non-null  object
#  2   Closed Date                     60270 non-null   object
#  3   Agency                          111069 non-null  object
#  4   Agency Name                     111069 non-null  object
#  5   Complaint Type                  111069 non-null  object
#  6   Descriptor                      110613 non-null  object
#  7   Location Type                   79022 non-null   object
#  8   Incident Zip                    98807 non-null   object
#  9   Incident Address                84441 non-null   object
#  10  Street Name                     84432 non-null   object
#  11  Cross Street 1                  84728 non-null   object
# ...

# %% [markdown]
# # 2.2 Sélectionner des colonnes et des lignes

# %% [markdown]
# Selectionner la colonne 'Complaint Type'.

# %%
colonne_complainType = df['Complaint Type']
print(colonne_complainType)
# Out:
# 0         Noise - Street/Sidewalk
# 1                 Illegal Parking
# 2              Noise - Commercial
# 3                 Noise - Vehicle
# 4                          Rodent
#                    ...
# 111064    Maintenance or Facility
# 111065            Illegal Parking
# 111066    Noise - Street/Sidewalk
# 111067         Noise - Commercial
# 111068           Blocked Driveway
# Name: Complaint Type, Length: 111069, dtype: object

# %% [markdown]
# Afficher les 5 premieres ligne de la colonne 'Complaint Type'.

# %%
colonne_complainType.head(5)
# Out:
# 0    Noise - Street/Sidewalk
# 1            Illegal Parking
# 2         Noise - Commercial
# 3            Noise - Vehicle
# 4                     Rodent
# Name: Complaint Type, dtype: object

# %% [markdown]
# Créer un nouveau dataframe avec seulement les lignes ayant la valeur 'HEATING' dans la colonne 'Complaint Type'.

# %%
# df_heating = df[colonne_complainType.str.contains("HEATING")]
#df_heating = df[colonne_complainType == 'HEATING']
df_heating = df.loc[colonne_complainType == 'HEATING']
df_heating
# Out:
#         Unique Key            Created Date             Closed Date Agency  \
# 59        26591688  10/31/2013 12:00:00 AM                     NaN    HPD
# 61        26593638  10/31/2013 12:00:00 AM                     NaN    HPD
# 62        26594900  10/31/2013 12:00:00 AM                     NaN    HPD
# 64        26591211  10/31/2013 12:00:00 AM                     NaN    HPD
# 3323      26593331  10/30/2013 12:00:00 AM                     NaN    HPD
# ...            ...                     ...                     ...    ...
# 107708    26441563  10/05/2013 12:00:00 AM  10/08/2013 12:00:00 AM    HPD
# 107709    26441561  10/05/2013 12:00:00 AM  10/08/2013 12:00:00 AM    HPD
# 107731    26441131  10/05/2013 12:00:00 AM  10/09/2013 12:00:00 AM    HPD
# 107734    26442050  10/05/2013 12:00:00 AM                     NaN    HPD
# 107735    26443736  10/05/2013 12:00:00 AM  10/09/2013 12:00:00 AM    HPD
#
#                                               Agency Name Complaint Type  \
# ...

# %% [markdown]
# # 2.3 Sélection de plusieurs colonnes

# %% [markdown]
# Afficher tous les noms de colonnes.

# %%
column_names = list(df.columns.values)
column_names
# Out:
# ['Unique Key',
#  'Created Date',
#  'Closed Date',
#  'Agency',
#  'Agency Name',
#  'Complaint Type',
#  'Descriptor',
#  'Location Type',
#  'Incident Zip',
#  'Incident Address',
#  'Street Name',
#  'Cross Street 1',
#  'Cross Street 2',
#  'Intersection Street 1',
#  'Intersection Street 2',
#  'Address Type',
#  'City',
#  'Landmark',
#  'Facility Type',
#  'Status',
#  'Due Date',
#  'Resolution Action Updated Date',
#  'Community Board',
#  'Borough',
#  'X Coordinate (State Plane)',
#  'Y Coordinate (State Plane)',
#  'Park Facility Name',
#  'Park Borough',
#  'School Name',
#  'School Number',
#  'School Region',
#  'School Code',
#  'School Phone Number',
#  'School Address',
#  'School City',
#  'School State',
#  'School Zip',
#  'School Not Found',
#  'School or Citywide Complaint',
#  'Vehicle Type',
#  'Taxi Company Borough',
#  'Taxi Pick Up Location',
#  'Bridge Highway Name',
#  'Bridge Highway Direction',
#  'Road Ramp',
#  'Bridge Highway Segment',
# ...

# %% [markdown]
# Créer un nouveaux dataset en selectionnant les colonnes 'Created Date', 'Closed Date', 'Complaint Type', 'Incident Address' et 'Street Name'

# %%
new_df = df.loc[:, ['Created Date','Closed Date', 'Complaint Type', 'Incident Address', 'Street Name']]
new_df
# Out:
#                   Created Date             Closed Date  \
# 0       10/31/2013 02:08:41 AM                     NaN
# 1       10/31/2013 02:01:04 AM                     NaN
# 2       10/31/2013 02:00:24 AM  10/31/2013 02:40:32 AM
# 3       10/31/2013 01:56:23 AM  10/31/2013 02:21:48 AM
# 4       10/31/2013 01:53:44 AM                     NaN
# ...                        ...                     ...
# 111064  10/04/2013 12:01:13 AM  10/07/2013 04:07:16 PM
# 111065  10/04/2013 12:01:05 AM  10/04/2013 02:13:50 AM
# 111066  10/04/2013 12:00:45 AM  10/04/2013 01:25:01 AM
# 111067  10/04/2013 12:00:28 AM  10/04/2013 04:17:32 AM
# 111068  10/04/2013 12:00:10 AM  10/04/2013 01:20:52 AM
#
#                  Complaint Type      Incident Address      Street Name
# 0       Noise - Street/Sidewalk      90-03 169 STREET       169 STREET
# 1               Illegal Parking             58 AVENUE        58 AVENUE
# 2            Noise - Commercial         4060 BROADWAY         BROADWAY
# ...

# %% [markdown]
# # 2.4 Quelles est la plainte qui revient le plus souvent?

# %% [markdown]
# Utiliser la méthode groupby pour compter le nombre de plaintes pour chaque type de plainte.

# %%
nb_complaint = df.groupby(by="Complaint Type").count().reset_index()
nb_complaint
# Out:
#               Complaint Type  Unique Key  Created Date  Closed Date  Agency  \
# 0                  APPLIANCE         445           445           44     445
# 1             Adopt-A-Basket           3             3            3       3
# 2              Agency Issues         174           174            0     174
# 3                Air Quality         459           459           12     459
# 4               Animal Abuse         164           164          164     164
# ..                       ...         ...           ...          ...     ...
# 160       Water Conservation         130           130           74     130
# 161            Water Quality          89            89           35      89
# 162             Water System        2636          2636         1511    2636
# 163             Window Guard           2             2            0       2
# 164  X-Ray Machine/Equipment           1             1            1       1
#
# ...

# %% [markdown]
# Utiliser la methode .sort() et afficher le top 10 des types de plainte avec le plus d'enregistremments.

# %%
sort_complaint = nb_complaint.sort_values(by=["Unique Key"], ascending=False).head(10)
sort_complaint = sort_complaint.loc[:, ['Complaint Type', 'Unique Key']].rename(columns={'Unique Key': 'Complaint Count'})
sort_complaint
# Out:
#              Complaint Type  Complaint Count
# 66                  HEATING            14200
# 63     GENERAL CONSTRUCTION             7471
# 139  Street Light Condition             7117
# 32   DOF Literature Request             5797
# 109                PLUMBING             5373
# 108         PAINT - PLASTER             5149
# 13         Blocked Driveway             4590
# 93                 NONCONST             3998
# 138        Street Condition             3473
# 76          Illegal Parking             3343

# %% [markdown]
# Utiliser la librairie matplotlib pour produire un graphique en barre de ce top 10.

# %%
names_complaints = sort_complaint['Complaint Type'].tolist()
values_complaints= sort_complaint['Complaint Count'].tolist()
y_pos = np.arange(len(sort_complaint))
plt.bar(y_pos, values_complaints, color='green', edgecolor='black')
plt.xticks(y_pos, names_complaints, rotation=90)
plt.title('Top 10 des plaintes')
plt.show()

# %% [markdown]
# Utiliser la librairie matplotlib pour produire un camenbert avec les pourcentages représentant la proportion de chaque type de plainte.

# %%
plt.pie(
    values_complaints,
    labels=names_complaints,
    labeldistance=1.15,
    autopct='%1.2f%%',
    wedgeprops = { 'linewidth' : 1, 'edgecolor' : 'white' },
);
plt.title("Proportion du top 10 des plaintes");
plt.show();

# %% [markdown]
# <style>
#     @font-face {
#         font-family: "Computer Modern";
#         src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
#     }
#     div.cell{
#         width:800px;
#         margin-left:16% !important;
#         margin-right:auto;
#     }
#     h1 {
#         font-family: Helvetica, serif;
#     }
#     h4{
#         margin-top:12px;
#         margin-bottom: 3px;
#        }
#     div.text_cell_render{
#         font-family: Computer Modern, "Helvetica Neue", Arial, Helvetica, Geneva, sans-serif;
#         line-height: 145%;
#         font-size: 130%;
#         width:800px;
#         margin-left:auto;
#         margin-right:auto;
#     }
#     .CodeMirror{
#             font-family: "Source Code Pro", source-code-pro,Consolas, monospace;
#     }
#     .text_cell_render h5 {
#         font-weight: 300;
#         font-size: 22pt;
#         color: #4057A1;
#         font-style: italic;
#         margin-bottom: .5em;
#         margin-top: 0.5em;
#         display: block;
#     }
#
#     .warning{
#         color: rgb( 240, 20, 20 )
#         }
